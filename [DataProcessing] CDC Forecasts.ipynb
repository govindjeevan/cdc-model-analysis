# %%
CDC_ROOT = "../data/covid19-forecast-hub/"

# %%
# !cd $CDC_ROOT && git pull
# Out:
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (427/427), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 706 (delta 414), reused 424 (delta 414), pack-reused 279
# Receiving objects: 100% (706/706), 110.65 MiB | 13.98 MiB/s, done.
# Resolving deltas: 100% (466/466), completed with 165 local objects.
# From https://github.com/reichlab/covid19-forecast-hub
#    59c0f6e4d..28da65d85  master            -> origin/master
#  * [new branch]          baseline-20211004 -> origin/baseline-20211004
#  * [new tag]             2021-10-04-COVIDhub-ensemble -> 2021-10-04-COVIDhub-ensemble
# Updating 59c0f6e4d..28da65d85
# Updating files: 100% (101/101), done.
# Fast-forward
#  .../2021-10-04-cum_death-model-eligibility.csv     |   1540 +
#  .../2021-10-04-cum_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_case-model-eligibility.csv      |  92830 +++++
#  .../2021-10-04-inc_case-model-weights.csv          |   3202 +
#  .../2021-10-04-inc_death-model-eligibility.csv     |   1654 +
#  .../2021-10-04-inc_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_hosp-model-eligibility.csv      |    496 +
#  .../2021-10-04-inc_hosp-model-weights.csv          |     56 +
#  code/validation/locally_validated_files.csv        |     59 +
#  code/validation/validated_files.csv                |     59 +
#  code/zoltar_scripts/validated_file_db.json         |     61 +-
#  .../AIpert-pwllnod/2021-10-04-AIpert-pwllnod.csv   |  21505 ++
#  .../2021-10-03-BPagano-RtDriven.csv                |  11873 +
#  data-processed/CEID-Walk/2021-10-04-CEID-Walk.csv  | 113345 ++++++
#  .../2021-10-04-COVIDhub-4_week_ensemble.csv        | 150337 ++++++++
#  .../2021-10-04-COVIDhub-baseline.csv               | 263713 ++++++++++++++
#  .../2021-10-04-COVIDhub-ensemble.csv               |  55033 +++
#  .../2021-10-04-COVIDhub-trained_ensemble.csv       | 150337 ++++++++
#  .../CU-nochange/2021-10-03-CU-nochange.csv         | 195457 +++++++++++
#  .../CU-scenario_low/2021-10-03-CU-scenario_low.csv | 195601 +++++++++++
#  .../CU-scenario_mid/2021-10-03-CU-scenario_mid.csv | 196129 +++++++++++
#  data-processed/CU-select/2021-10-03-CU-select.csv  | 195601 +++++++++++
#  .../2021-10-03-CUBoulder-COVIDLSTM.csv             |  99457 ++++++
#  .../2021-10-04-CovidAnalytics-DELPHI.csv           |  17473 +
#  data-processed/DDS-NBDS/2021-10-04-DDS-NBDS.csv    |   9985 +
#  data-processed/FAIR-NRAR/2021-09-30-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-01-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-02-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-03-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-04-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-05-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-06-FAIR-NRAR.csv  | 100417 ++++++
#  data-processed/FAIR-NRAR/2021-10-07-FAIR-NRAR.csv  | 100417 ++++++
#  .../2021-10-04-FDANIHASU-Sweight.csv               |    193 +
#  .../2021-10-04-FRBSF_Wilson-Econometric.csv        |  55681 +++
#  .../GT-DeepCOVID/2021-10-04-GT-DeepCOVID.csv       |  43057 +++
#  .../2021-10-04-Google_Harvard-CPF.csv              |  17869 +
#  data-processed/HKUST-DNN/2021-10-04-HKUST-DNN.csv  |   4897 +
#  .../2021-10-04-IEM_MED-CovidProject.csv            |   7041 +
#  .../JHUAPL-Bucky/2021-10-04-JHUAPL-Bucky.csv       | 322169 ++++++++++++++++++
#  .../JHUAPL-Gecko/2021-10-03-JHUAPL-Gecko.csv       |  45361 +++
#  .../JHU_CSSE-DECOM/2021-10-03-JHU_CSSE-DECOM.csv   |  12513 +
#  .../2021-10-03-JHU_UNC_GAS-StatMechPool.csv        | 100385 ++++++
#  .../2021-10-04-KITmetricslab-select_ensemble.csv   |  11649 +
#  .../Karlen-pypm/2021-10-03-Karlen-pypm.csv         |  53001 +++
#  .../MIT-Cassandra/2021-10-04-MIT-Cassandra.csv     |  13721 +
#  .../2021-10-03-MIT_CritData-GBCF.csv               |   9985 +
#  .../2021-10-04-MIT_ISOLAT-Mixtures.csv             |   5537 +
#  .../2021-10-04-MOBS-GLEAM_COVID.csv                |  46921 +++
#  .../MUNI-ARIMA/2021-10-04-MUNI-ARIMA.csv           |   6657 +
#  .../2021-10-04-Microsoft-DeepSTIA.csv              |  24217 ++
#  data-processed/PSI-DRAFT/2021-10-04-PSI-DRAFT.csv  |  15841 +
#  .../2021-10-03-PandemicCentral-COVIDForest.csv     |  98177 ++++++
#  .../2021-10-08-PandemicCentral-COVIDForest.csv     |  98177 ++++++
#  .../2021-10-04-QJHong-Encounter.csv                |    377 +
#  .../2021-10-04-RobertWalraven-ESG.csv              |  12545 +
#  .../2021-10-03-SDSC_ISG-TrendModel.csv             |    172 +
#  .../2021-10-04-SteveMcConnell-CovidComplete.csv    |   9985 +
#  .../TTU-squider/2021-10-03-TTU-squider.csv         |    637 +
#  .../UA-EpiCovDA/2021-10-04-UA-EpiCovDA.csv         |  10177 +
#  data-processed/UCF-AEM/2021-10-03-UCF-AEM.csv      |     65 +
#  .../2021-10-04-UCSD_NEU-DeepGLEAM.csv              |   9793 +
#  .../UMass-MechBayes/2021-10-03-UMass-MechBayes.csv |  10945 +
#  .../2021-10-04-UMich-RidgeTfReg.csv                |  10977 +
#  .../USC-SI_kJalpha/2021-09-26-USC-SI_kJalpha.csv   | 178135 ++++++++++
#  .../USC-SI_kJalpha/2021-10-03-USC-SI_kJalpha.csv   | 178135 ++++++++++
#  .../UT_GISAG-SPDM/2021-10-04-UT_GISAG-SPDM.csv     |   8249 +
#  .../UT_GISAG-SPDM/metadata-UT_GISAG-SPDM.txt       |     20 +
#  .../UVA-Ensemble/2021-10-04-UVA-Ensemble.csv       | 101889 ++++++
#  .../2021-10-04-epiforecasts-ensemble1.csv          |  10945 +
#  data-truth/nytimes/raw/us-counties.csv             |  45486 +++
#  data-truth/nytimes/raw/us-states.csv               |    784 +
#  data-truth/nytimes/raw/us.csv                      |     14 +
#  .../nytimes/truth_nytimes-Cumulative Cases.csv     |  46284 +++
#  .../nytimes/truth_nytimes-Cumulative Deaths.csv    |  46284 +++
#  .../nytimes/truth_nytimes-Incident Cases.csv       |  46284 +++
#  .../nytimes/truth_nytimes-Incident Deaths.csv      |  46284 +++
#  data-truth/truth-Cumulative Cases.csv              |  70900 +++-
#  data-truth/truth-Cumulative Deaths.csv             |  54188 ++-
#  data-truth/truth-Cumulative Hospitalizations.csv   |    421 +-
#  data-truth/truth-Incident Cases.csv                |  51848 ++-
#  data-truth/truth-Incident Deaths.csv               |  47744 ++-
#  data-truth/truth-Incident Hospitalizations.csv     |  48236 +--
#  data-truth/zoltar-truth.csv                        |  51613 +--
#  .../2021-10-04-cum_death-model-eligibility.csv     |   1540 +
#  .../2021-10-04-cum_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_case-model-eligibility.csv      |  92830 +++++
#  .../2021-10-04-inc_case-model-weights.csv          |   3202 +
#  .../2021-10-04-inc_death-model-eligibility.csv     |   1654 +
#  .../2021-10-04-inc_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_hosp-model-eligibility.csv      |    496 +
#  .../2021-10-04-inc_hosp-model-weights.csv          |     56 +
#  .../2021-10-04-cum_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_case-model-weights.csv          |   3202 +
#  .../2021-10-04-inc_death-model-weights.csv         |     58 +
#  .../2021-10-04-inc_hosp-model-weights.csv          |     56 +
#  trained_ensemble-metadata/thetas.csv               |     19 +
#  .../dist/truth/Cumulative Cases.json               |      2 +-
#  .../dist/truth/Cumulative Deaths.json              |      2 +-
#  .../covid-csv-tools/dist/truth/Incident Cases.json |      2 +-
#  .../dist/truth/Incident Deaths.json                |      2 +-
#  101 files changed, 4702977 insertions(+), 72038 deletions(-)
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-cum_death-model-eligibility.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-cum_death-model-weights.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_case-model-eligibility.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_case-model-weights.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_death-model-eligibility.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_death-model-weights.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_hosp-model-eligibility.csv
#  create mode 100644 4_week_ensemble-metadata/2021-10-04-inc_hosp-model-weights.csv
#  create mode 100644 data-processed/AIpert-pwllnod/2021-10-04-AIpert-pwllnod.csv
#  create mode 100644 data-processed/BPagano-RtDriven/2021-10-03-BPagano-RtDriven.csv
#  create mode 100644 data-processed/CEID-Walk/2021-10-04-CEID-Walk.csv
#  create mode 100644 data-processed/COVIDhub-4_week_ensemble/2021-10-04-COVIDhub-4_week_ensemble.csv
#  create mode 100644 data-processed/COVIDhub-baseline/2021-10-04-COVIDhub-baseline.csv
#  create mode 100644 data-processed/COVIDhub-ensemble/2021-10-04-COVIDhub-ensemble.csv
#  create mode 100644 data-processed/COVIDhub-trained_ensemble/2021-10-04-COVIDhub-trained_ensemble.csv
#  create mode 100644 data-processed/CU-nochange/2021-10-03-CU-nochange.csv
#  create mode 100644 data-processed/CU-scenario_low/2021-10-03-CU-scenario_low.csv
#  create mode 100644 data-processed/CU-scenario_mid/2021-10-03-CU-scenario_mid.csv
#  create mode 100644 data-processed/CU-select/2021-10-03-CU-select.csv
#  create mode 100644 data-processed/CUBoulder-COVIDLSTM/2021-10-03-CUBoulder-COVIDLSTM.csv
#  create mode 100644 data-processed/CovidAnalytics-DELPHI/2021-10-04-CovidAnalytics-DELPHI.csv
#  create mode 100644 data-processed/DDS-NBDS/2021-10-04-DDS-NBDS.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-09-30-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-01-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-02-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-03-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-04-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-05-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-06-FAIR-NRAR.csv
#  create mode 100644 data-processed/FAIR-NRAR/2021-10-07-FAIR-NRAR.csv
#  create mode 100644 data-processed/FDANIHASU-Sweight/2021-10-04-FDANIHASU-Sweight.csv
#  create mode 100644 data-processed/FRBSF_Wilson-Econometric/2021-10-04-FRBSF_Wilson-Econometric.csv
#  create mode 100644 data-processed/GT-DeepCOVID/2021-10-04-GT-DeepCOVID.csv
#  create mode 100644 data-processed/Google_Harvard-CPF/2021-10-04-Google_Harvard-CPF.csv
#  create mode 100644 data-processed/HKUST-DNN/2021-10-04-HKUST-DNN.csv
#  create mode 100644 data-processed/IEM_MED-CovidProject/2021-10-04-IEM_MED-CovidProject.csv
#  create mode 100644 data-processed/JHUAPL-Bucky/2021-10-04-JHUAPL-Bucky.csv
#  create mode 100644 data-processed/JHUAPL-Gecko/2021-10-03-JHUAPL-Gecko.csv
#  create mode 100644 data-processed/JHU_CSSE-DECOM/2021-10-03-JHU_CSSE-DECOM.csv
#  create mode 100644 data-processed/JHU_UNC_GAS-StatMechPool/2021-10-03-JHU_UNC_GAS-StatMechPool.csv
#  create mode 100644 data-processed/KITmetricslab-select_ensemble/2021-10-04-KITmetricslab-select_ensemble.csv
#  create mode 100644 data-processed/Karlen-pypm/2021-10-03-Karlen-pypm.csv
#  create mode 100644 data-processed/MIT-Cassandra/2021-10-04-MIT-Cassandra.csv
#  create mode 100644 data-processed/MIT_CritData-GBCF/2021-10-03-MIT_CritData-GBCF.csv
#  create mode 100644 data-processed/MIT_ISOLAT-Mixtures/2021-10-04-MIT_ISOLAT-Mixtures.csv
#  create mode 100644 data-processed/MOBS-GLEAM_COVID/2021-10-04-MOBS-GLEAM_COVID.csv
#  create mode 100644 data-processed/MUNI-ARIMA/2021-10-04-MUNI-ARIMA.csv
#  create mode 100644 data-processed/Microsoft-DeepSTIA/2021-10-04-Microsoft-DeepSTIA.csv
#  create mode 100644 data-processed/PSI-DRAFT/2021-10-04-PSI-DRAFT.csv
#  create mode 100644 data-processed/PandemicCentral-COVIDForest/2021-10-03-PandemicCentral-COVIDForest.csv
#  create mode 100644 data-processed/PandemicCentral-COVIDForest/2021-10-08-PandemicCentral-COVIDForest.csv
#  create mode 100644 data-processed/QJHong-Encounter/2021-10-04-QJHong-Encounter.csv
#  create mode 100644 data-processed/RobertWalraven-ESG/2021-10-04-RobertWalraven-ESG.csv
#  create mode 100644 data-processed/SDSC_ISG-TrendModel/2021-10-03-SDSC_ISG-TrendModel.csv
#  create mode 100644 data-processed/SteveMcConnell-CovidComplete/2021-10-04-SteveMcConnell-CovidComplete.csv
#  create mode 100644 data-processed/TTU-squider/2021-10-03-TTU-squider.csv
#  create mode 100644 data-processed/UA-EpiCovDA/2021-10-04-UA-EpiCovDA.csv
#  create mode 100644 data-processed/UCF-AEM/2021-10-03-UCF-AEM.csv
#  create mode 100644 data-processed/UCSD_NEU-DeepGLEAM/2021-10-04-UCSD_NEU-DeepGLEAM.csv
#  create mode 100644 data-processed/UMass-MechBayes/2021-10-03-UMass-MechBayes.csv
#  create mode 100644 data-processed/UMich-RidgeTfReg/2021-10-04-UMich-RidgeTfReg.csv
#  create mode 100644 data-processed/USC-SI_kJalpha/2021-09-26-USC-SI_kJalpha.csv
#  create mode 100644 data-processed/USC-SI_kJalpha/2021-10-03-USC-SI_kJalpha.csv
#  create mode 100644 data-processed/UT_GISAG-SPDM/2021-10-04-UT_GISAG-SPDM.csv
#  create mode 100644 data-processed/UT_GISAG-SPDM/metadata-UT_GISAG-SPDM.txt
#  create mode 100644 data-processed/UVA-Ensemble/2021-10-04-UVA-Ensemble.csv
#  create mode 100644 data-processed/epiforecasts-ensemble1/2021-10-04-epiforecasts-ensemble1.csv
#  create mode 100644 ensemble-metadata/2021-10-04-cum_death-model-eligibility.csv
#  create mode 100644 ensemble-metadata/2021-10-04-cum_death-model-weights.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_case-model-eligibility.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_case-model-weights.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_death-model-eligibility.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_death-model-weights.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_hosp-model-eligibility.csv
#  create mode 100644 ensemble-metadata/2021-10-04-inc_hosp-model-weights.csv
#  create mode 100644 trained_ensemble-metadata/2021-10-04-cum_death-model-weights.csv
#  create mode 100644 trained_ensemble-metadata/2021-10-04-inc_case-model-weights.csv
#  create mode 100644 trained_ensemble-metadata/2021-10-04-inc_death-model-weights.csv
#  create mode 100644 trained_ensemble-metadata/2021-10-04-inc_hosp-model-weights.csv
#  create mode 100644 trained_ensemble-metadata/thetas.csv

# %%
CDC_ROOT = "../data/covid19-forecast-hub/data-processed/"

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt 
import os
from tqdm import tqdm
import numpy as np

# %%
all_files = glob.glob(os.path.join(CDC_ROOT,"*", "*.csv"))
print(len(all_files))
# Out:
# 4598

# %%
data = []
prev = 0 
for filename in tqdm(all_files):
    model_name = filename.split("/")[-2]
    df = pd.read_csv(filename, index_col=None, header=0)
    df = df[(df.target.str.endswith('wk ahead inc case')) & (df.type=="point") & (df.location=="US")].reset_index(drop=True).drop(['quantile'], axis=1)
    df["model"]=model_name
    data.append(df)
# Out:
#   2%|▏         | 89/4598 [00:12<14:47,  5.08it/s]/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#  13%|█▎        | 598/4598 [01:56<28:27,  2.34it/s]/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 100%|██████████| 4598/4598 [19:52<00:00,  3.85it/s]

# %%
us_df = pd.concat(data, axis=0, ignore_index=True)

# %%
us_df["point"] = us_df["value"]
us_df["Model"] = us_df["model"]
us_df = us_df.drop(["type", "value", "model"], axis=1)

# %%
us_df.to_csv("processed_data/cdc-inc-cases.csv")

# %%
us_df
# Out:
#       location               target forecast_date target_end_date  \
# 0           US  1 wk ahead inc case    2020-08-24      2020-08-29
# 1           US  2 wk ahead inc case    2020-08-24      2020-09-05
# 2           US  3 wk ahead inc case    2020-08-24      2020-09-12
# 3           US  4 wk ahead inc case    2020-08-24      2020-09-19
# 4           US  1 wk ahead inc case    2021-02-01      2021-02-06
# ...        ...                  ...           ...             ...
# 12724       US  4 wk ahead inc case    2020-07-05      2020-08-01
# 12725       US  5 wk ahead inc case    2020-07-05      2020-08-08
# 12726       US  6 wk ahead inc case    2020-07-05      2020-08-15
# 12727       US  7 wk ahead inc case    2020-07-05      2020-08-22
# 12728       US  8 wk ahead inc case    2020-07-05      2020-08-29
#
#                point                     Model
# 0      276838.000000  COVIDhub-4_week_ensemble
# 1      248911.000000  COVIDhub-4_week_ensemble
# 2      229078.000000  COVIDhub-4_week_ensemble
# 3      204716.000000  COVIDhub-4_week_ensemble
# 4      995685.000000  COVIDhub-4_week_ensemble
# ...              ...                       ...
# 12724  514387.506835      Covid19Sim-Simulator
# 12725  563577.670062      Covid19Sim-Simulator
# 12726  616618.859130      Covid19Sim-Simulator
# 12727  672537.881971      Covid19Sim-Simulator
# 12728  730261.250238      Covid19Sim-Simulator
#
# [12729 rows x 6 columns]
