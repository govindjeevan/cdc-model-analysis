# %%
import data_load
import pandas as pd
import glob
import matplotlib.pyplot as plt 
import numpy as np
from datetime import datetime, timedelta

# %%
jhu_weekly = data_load.get_jhu_dataframe_weekly ()

# %%
from matplotlib.pyplot import figure
figure(figsize=(12, 6), dpi=100)
plt.plot(jhu_weekly,  zorder = 1)
plt.axvspan("2020-07-06", "2020-08-31", facecolor='r', alpha=0.5, zorder=1)
plt.axvspan("2020-08-31", "2021-02-14", facecolor='c', alpha=0.5, zorder=1)
plt.axvspan("2021-02-14", "2021-06-25", facecolor='y', alpha=0.5, zorder=1)
plt.axvspan("2021-06-25", "2021-10-10", facecolor='g', alpha=0.5, zorder=1)

plt.savefig('plots/time_segment.png', bbox_inches='tight', dpi=150)
